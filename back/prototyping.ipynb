# %%
from modules.core.ship.factory import ShipFactory
# Out:
# usage: ipykernel_launcher.py [-h] [-c CONFIG]
# ipykernel_launcher.py: error: unrecognized arguments: --f=c:\Users\ktess\AppData\Roaming\jupyter\runtime\kernel-v3a8bcea4d2f4526bd84cf409e1890d52fb9cb11ea.json
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
